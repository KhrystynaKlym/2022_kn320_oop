# %%
import os
import sys
import datetime

print(os.name)
print(os.environ)

os.path
# Out:
# nt
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\NewUser\\AppData\\Roaming', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_5512_JDSQSPLARZLKRHIP', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-5TQDCMV', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'ELECTRON_RUN_AS_NODE': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\NewUser', 'JPY_INTERRUPT_EVENT': '1452', 'LOCALAPPDATA': 'C:\\Users\\NewUser\\AppData\\Local', 'LOGONSERVER': '\\\\DESKTOP-5TQDCMV', 'NUMBER_OF_PROCESSORS': '12', 'ONEDRIVE': 'C:\\Users\\NewUser\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\NewUser\\AppData\\Local\\Programs\\Python\\Python310;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files (x86)\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Program Files\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Program Files\\Docker\\Docker\\resources\\bin;C:\\ProgramData\\DockerDesktop\\version-bin;C:\\Program Files\\dotnet\\;C:\\Program Files\\Git\\cmd;C:\\Program Files (x86)\\CodeBlocks\\MinGW;C:\\Program Files (x86)\\CodeBlocks\\MinGW\\bin;C:\\Users\\NewUser\\AppData\\Local\\Microsoft\\WindowsApps;;C:\\Users\\NewUser\\AppData\\Local\\Programs\\Microsoft VS Code\\bin', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 158 Stepping 10, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': '9e0a', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'PYTHONIOENCODING': 'utf-8', 'PYTHONUNBUFFERED': '1', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\NewUser\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\NewUser\\AppData\\Local\\Temp', 'USERDOMAIN': 'DESKTOP-5TQDCMV', 'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-5TQDCMV', 'USERNAME': 'NewUser', 'USERPROFILE': 'C:\\Users\\NewUser', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\NewUser\\AppData\\Roaming\\Code\\CachedData\\74b1f979648cc44d385a2286793c226e611f59e7', 'VSCODE_CWD': 'C:\\Users\\NewUser\\AppData\\Local\\Programs\\Microsoft VS Code', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '\\\\.\\pipe\\514cf9e665c4fe3809c25ae195ffc085-1.71.2-main-sock', 'VSCODE_NLS_CONFIG': '{"locale":"uk","availableLanguages":{},"_languagePackSupport":true}', 'VSCODE_PID': '5512', 'WINDIR': 'C:\\WINDOWS', 'ZES_ENABLE_SYSMAN': '1', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1'})
# <module 'ntpath' from 'c:\\Users\\NewUser\\AppData\\Local\\Programs\\Python\\Python310\\lib\\ntpath.py'>

# %% [markdown]
# ### Бібліотека numpy

# %%
import numpy as np

a = np.arange(6)
a2 = a[np.newaxis, :]
a2.shape
print(a2)
# Out:
# [[0 1 2 3 4 5]]

# %% [markdown]
# ### Бібліотека requests

# %%
import requests

r = requests.get('https://api.github.com/events')
print(r.content)
# Out:
# b'[{"id":"24431908251","type":"PushEvent","actor":{"id":8517910,"login":"LombiqBot","display_login":"LombiqBot","gravatar_id":"","url":"https://api.github.com/users/LombiqBot","avatar_url":"https://avatars.githubusercontent.com/u/8517910?"},"repo":{"id":410004154,"name":"Lombiq/TheBootstrapTheme","url":"https://api.github.com/repos/Lombiq/TheBootstrapTheme"},"payload":{"push_id":11242616200,"size":0,"distinct_size":0,"ref":"refs/heads/master","head":"66f29e3675bf9298d7a701140adcdec189f17ce1","before":"66f29e3675bf9298d7a701140adcdec189f17ce1","commits":[]},"public":true,"created_at":"2022-10-06T08:44:35Z","org":{"id":8158177,"login":"Lombiq","gravatar_id":"","url":"https://api.github.com/orgs/Lombiq","avatar_url":"https://avatars.githubusercontent.com/u/8158177?"}},{"id":"24431908343","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":228467337,"name":"BabsLabs/code_songs_microservice","url":"https://api.github.com/repos/BabsLabs/code_songs_microservice"},"payload":{"action":"closed","number":41,"pull_request":{"url":"https://api.github.com/repos/BabsLabs/code_songs_microservice/pulls/41","id":688526039,"node_id":"MDExOlB1bGxSZXF1ZXN0Njg4NTI2MDM5","html_url":"https://github.com/BabsLabs/code_songs_microservice/pull/41","diff_url":"https://github.com/BabsLabs/code_songs_microservice/pull/41.diff","patch_url":"https://github.com/BabsLabs/code_songs_microservice/pull/41.patch","issue_url":"https://api.github.com/repos/BabsLabs/code_songs_microservice/issues/41","number":41,"state":"closed","locked":false,"title":"Bump addressable from 2.7.0 to 2.8.0","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMzM=","avatar_url":"https://avatars.githubusercontent.com/in/29110?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot%5Bbot%5D","html_url":"https://github.com/apps/dependabot","followers_url":"https://api.github.com/users/dependabot%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [addressable](https://github.com/sporkmonger/addressable) from 2.7.0 to 2.8.0.\\n<details>\\n<summary>Changelog</summary>\\n<p><em>Sourced from <a href=\\"https://github.com/sporkmonger/addressable/blob/main/CHANGELOG.md\\">addressable\'s changelog</a>.</em></p>\\n<blockquote>\\n<h1>Addressable 2.8.0</h1>\\n<ul>\\n<li>fixes ReDoS vulnerability in Addressable::Template#match</li>\\n<li>no longer replaces <code>+</code> with spaces in queries for non-http(s) schemes</li>\\n<li>fixed encoding ipv6 literals</li>\\n<li>the <code>:compacted</code> flag for <code>normalized_query</code> now dedupes parameters</li>\\n<li>fix broken <code>escape_component</code> alias</li>\\n<li>dropping support for Ruby 2.0 and 2.1</li>\\n<li>adding Ruby 3.0 compatibility for development tasks</li>\\n<li>drop support for <code>rack-mount</code> and remove Addressable::Template#generate</li>\\n<li>performance improvements</li>\\n<li>switch CI/CD to GitHub Actions</li>\\n</ul>\\n</blockquote>\\n</details>\\n<details>\\n<summary>Commits</summary>\\n<ul>\\n<li><a href=\\"https://github.com/sporkmonger/addressable/commit/6469a232c0f1892809ff66737370c765d574e16c\\"><code>6469a23</code>< ...

# %%
import requests

r = requests.get('https://google.com')
print(r.text)
print(r.status_code)
print(r.encoding)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="uk"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="oVjZmDNgfg6rGnaKKl4oaQ">(function(){window.google={kEI:'dBo_Y-uMJOfw4-EPnMm90AI',kEXPI:'0,202547,1099989,56873,6058,207,4804,2316,383,246,5,5367,1123753,1197720,681,380090,16114,28684,22430,1362,283,12030,17586,4998,13228,3847,3599,7023,22741,5081,1593,1279,2742,149,1103,840,6297,108,3406,606,2023,1777,520,14670,3229,2844,8,5597,19391,8781,1850,2614,13142,3,576,6460,148,13975,4,1528,2304,7039,20309,7422,7357,11443,2215,4437,16786,5806,2551,4094,4052,3,3541,1,11942,30212,2,14022,14116,11623,5679,1020,2381,28742,4567,6256,23421,1252,5835,14967,4333,22,7462,445,2,2,1,6960,19672,8047,108,7381,15969,873,14838,4796,7,1922,9780,7782,12856,1140,9543,4832,1520,4241,2173,9082,122,700,4,1,2,2,2,2,15123,16,2307,1605,1415,8323,14,82,950,807,1096,1037,751,202,1866,3285,1653,409,2210,164,2019,451,102,922,861,1080,558,255,989,161,507,3099,51,166,337,3,2,2,399,499,109,456,931,194,715,824,4310,1,866,85
a></div></div><p style="font-size:8pt;color:#70757a">&copy; 2022</p></span></center><script nonce="oVjZmDNgfg6rGnaKKl4oaQ">(function(){window.google.cdo={height:757,width:1440};(function(){
# var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log("","","/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI);}).call(this);})();</script> <script nonce="oVjZmDNgfg6rGnaKKl4oaQ">(function(){google.xjs={ck:'xjs.hp.CXK6HVSmUM8.L.X.O',cs:'ACT90oHKDB7FigLSOFRGZ-PhvSDWfD9arA',excm:[]};})();</script>  <script nonce="oVjZmDNgfg6rGnaKKl4oaQ">(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.afnwz8scFFk.O/am\x3dAACeAAAUAKg/d\x3d1/ed\x3d1/rs\x3dACT90oGZUrtp-rYz1qZgIdvoIYF6uNBATQ/m\x3dsb_he,d';
# var d=this||self,e=function(a){return a};
# var g;var l=function(a,b){this.g=b===h?a:""};l.prototype.toString=function(){return this.g+""};var h={};function n(){var a=u;google.lx=function(){p(a);google.lx=function(){}};google.bx||google.lx()}
# function p(a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=document;var c="SCRIPT";"application/xhtml+xml"===b.contentType&&(c=c.toLowerCase());c=b.createElement(c);if(void 0===g){b=null;var k=d.trustedTypes;if(k&&k.createPolicy){try{b=k.createPolicy("goog#html",{createHTML:e,createScript:e,createScriptURL:e})}catch(q){d.console&&d.console.error(q.message)}g=b}else g=b}a=(b=g)?b.createScriptURL(a):a;a=new l(a,h);c.src=a instanceof l&&a.constructor===l?a.g:"type_error:TrustedResourceUrl";var f,m;(f=(a=null==(m=(f=(c.ownerDocument&&c.ownerDocument.defaultView||window).document).querySelector)?void 0:m.call(f,"script[nonce]"))?a.nonce||a.getAttribute("nonce")||"":"")&&c.setAttribute("nonce",f);document.body.appendChild(c);google.psa=!0};google.xjsu=u;setTimeout(function(){n()},0);})();function _DumpException(e){throw e;}
# function _F_installCss(c){}
# (function(){google.jl={blt:'none',chnk:0,dw:false,dwu:true,emtn:0,end:0,ine:false,injs:'none',injt:0,injth:0,injv2:false,lls:'default',pdt:0,rep:0,snet:true,strt:0,ubm:false,uwp:true};})();(function(){var pmc='{\x22d\x22:{},\x22sb_he\x22:{\x22agen\x22:true,\x22cgen\x22:true,\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22dhqt\x22:true,\x22ds\x22:\x22\x22,\x22ffql\x22:\x22en\x22,\x22fl\x22:true,\x22host\x22:\x22google.com\x22,\x22isbh\x22:28,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22&#1054;&#1095;&#1080;&#1089;&#1090;&#1080;&#1090;&#1080; &#1087;&#1086;&#1096;&#1091;&#1082;&#1086;&#1074;&#1080;&#1081; &#1079;&#1072;&#1087;&#1080;&#1090;\x22,\x22dym\x22:\x22&#1052;&#1086;&#1078;&#1083;&#1080;&#1074;&#1086;, &#1074;&#1080; &#1084;&#1072;&#1083;&#1080; &#1085;&#1072; &#1091;&#1074;&#1072;&#1079;&#1110;:\x22,\x22lcky\x22:\x22&#1052;&#1077;&#1085;&#1110; &#1087;&#1086;&#1097;&#1072;&#1089;&#1090;&#1080;&#1090;&#1100;\x22,\x22lml\x22:\x22&#1044;&#1086;&#1082;&#1083;&#1072;&#1076;&#1085;&#1110;&#1096;&#1077;\x22,\x22oskt\x22:\x22&#1058;&#1088;&#1072;&#1085;&#1089;&#1083;&#1110;&#1090;&#1077;&#1088;&#1072;&#1094;&#1110;&#1103;\x22,\x22psrc\x22:\x22&#1062;&#1077;&#1081; &#1087;&#1086;&#1096;&#1091;&#1082; &#1074;&#1080;&#1076;&#1072;&#1083;&#1077;&#1085;&#1086; &#1079; &#1074;&#1072;&#1096;&#1086;&#1111; \\u003Ca href\x3d\\\x22/history\\\x22\\u003E&#1074;&#1077;&#1073;-&#1110;&#1089;&#1090;&#1086;&#1088;&#1110;&#1111;\\u003C/a\\u003E\x22,\x22psrl\x22:\x22&#1042;&#1080;&#1076;&#1072;&#1083;&#1080;&#1090;&#1080;\x22,\x22sbit\x22:\x22&#1055;&#1086;&#1096;&#1091;&#1082; &#1079;&#1072; &#1079;&#1086;&#1073;&#1088;&#1072;&#1078;&#1077;&#1085;&#1085;&#1103;&#1084;\x22,\x22srch\x22:\x22&#1055;&#1086;&#1096;&#1091;&#1082; Google\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22refpd\x22:true,\x22rfs\x22:[],\x22sbas\x22:\x220 3px 8px 0 rgba(0,0,0,0.2),0 0 0 1px rgba(0,0,0,0.08)\x22,\x22sbpl\x22:16,\x22sbpr\x22:16,\x22scd\x22:10,\x22stok\x22:\x22MJBvdTq9ameUcP31cqzJQI0TEkk\x22,\x22uhde\x22:false}}';google.pmc=JSON.parse(pmc);})();</script>        </body></html>
# 200
# ISO-8859-1

# %% [markdown]
# ### Заголовки відповідей

# %%
import requests

url = 'https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}

r = requests.get(url, headers=headers)
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Thu, 06 Oct 2022 18:31:17 GMT', 'Content-Type': 'application/json; charset=utf-8', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Vary': 'Accept-Encoding, Accept, X-Requested-With', 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '51', 'X-RateLimit-Reset': '1665083243', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '9', 'Content-Length': '91', 'X-GitHub-Request-Id': 'A406:EC6F:1928BFE:1986AFF:633F1EF5'}
